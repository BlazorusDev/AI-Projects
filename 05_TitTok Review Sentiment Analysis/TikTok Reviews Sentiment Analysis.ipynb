# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
import string
import re
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")

data = pd.read_csv("tiktok_google_play_reviews.csv")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# C:\Users\acer\AppData\Local\Temp\ipykernel_388\1299459330.py:12: DtypeWarning: Columns (0: replyContent, 1: repliedAt) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("tiktok_google_play_reviews.csv")

# %%
data.head()
# Out:
#                                reviewId              userName  \
# 0  68ccaec8-1415-4301-a85e-3004679a3a83          Cassie Moore
# 1  d84cbfd3-6aa3-485c-aaf9-c5dca27dc966         Kaleb Plummer
# 2  96618aa1-31e5-4259-8649-89b75d962f00           Rylee Maher
# 3  078c0bda-598b-474e-a04e-d7cb3e6f6301  Kittykatelyn Romilly
# 4  8e68c5cd-b12a-4206-a8da-6bfdbff44ae3      Loveness Malenga
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ALm5wu...
# 1  https://play-lh.googleusercontent.com/a-/ACNPE...
# 2  https://play-lh.googleusercontent.com/a/ALm5wu...
# 3  https://play-lh.googleusercontent.com/a-/ACNPE...
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                              content  score  thumbsUpCount  \
# 0                                           No words      5              0
# 1                              Great fun app so far!      5              0
# 2  The app would get a higher rating but I litera...      1              0
# 3  I WISH I COULD GIVE THIS A 100 PERCENT RATING ...      5              0
# 4                                Pictures and record      5              0
#
#   reviewCreatedVersion                   at replyContent repliedAt
# 0               27.1.3  2022-11-29 21:55:37          NaN       NaN
# 1                  NaN  2022-11-29 21:55:04          NaN       NaN
# 2               27.1.3  2022-11-29 21:54:48          NaN       NaN
# 3                  NaN  2022-11-29 21:54:35          NaN       NaN
# 4                  NaN  2022-11-29 21:54:21          NaN       NaN

# %%
data = data[["content", "score"]]
data.head()
# Out:
#                                              content  score
# 0                                           No words      5
# 1                              Great fun app so far!      5
# 2  The app would get a higher rating but I litera...      1
# 3  I WISH I COULD GIVE THIS A 100 PERCENT RATING ...      5
# 4                                Pictures and record      5

# %%
print(data.isnull().sum())
# Out:
# content    31
# score       0
# dtype: int64

# %%
data = data.dropna()

# %%
data.head()
# Out:
#                                              content  score
# 0                                           No words      5
# 1                              Great fun app so far!      5
# 2  The app would get a higher rating but I litera...      1
# 3  I WISH I COULD GIVE THIS A 100 PERCENT RATING ...      5
# 4                                Pictures and record      5

# %%
data.isnull().sum()
# Out:
# content    0
# score      0
# dtype: int64

# %%
stopword=set(stopwords.words('english'))
def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\acer\AppData\Local\Temp\ipykernel_388\2467037720.py:4: SyntaxWarning: invalid escape sequence '\['
#   text = re.sub('\[.*?\]', '', text)
# C:\Users\acer\AppData\Local\Temp\ipykernel_388\2467037720.py:5: SyntaxWarning: invalid escape sequence '\S'
#   text = re.sub('https?://\S+|www\.\S+', '', text)
# C:\Users\acer\AppData\Local\Temp\ipykernel_388\2467037720.py:9: SyntaxWarning: invalid escape sequence '\w'
#   text = re.sub('\w*\d\w*', '', text)

# %%
clean("you are beauty")
# Out:
# 'beauti'

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 460256 entries, 0 to 460286
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   content  460256 non-null  str
#  1   score    460256 non-null  int64
# dtypes: int64(1), str(1)
# memory usage: 10.5 MB

# %%
ratings = data["score"].value_counts()
numbers = ratings.index
quantity = ratings.values
import plotly.express as px
figure = px.pie(data, 
             values=quantity, 
             names=numbers,hole = 0.5)
figure.show()
# Out:
# ---------------------------------------------------------------------------
# ShapeError                                Traceback (most recent call last)
# Cell In[16], line 5
#       3 quantity = ratings.values
#       4 import plotly.express as px
# ----> 5 figure = px.pie(data,
#       6              values=quantity,
#       7              names=numbers,hole = 0.5)
#       8 figure.show()
#
# File e:\AI Projects\myenv\Lib\site-packages\plotly\express\_chart_types.py:1721, in pie(data_frame, names, values, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, category_orders, labels, title, subtitle, template, width, height, opacity, hole)
#    1719 else:
#    1720     layout_patch = {}
# -> 1721 return make_figure(
#    1722     args=locals(),
#    1723     constructor=go.Pie,
#    1724     trace_patch=dict(showlegend=(names is not None), hole=hole),
#    1725     layout_patch=layout_patch,
#    1726 )
#
# File e:\AI Projects\myenv\Lib\site-packages\plotly\express\_core.py:2511, in make_figure(args, constructor, trace_patch, layout_patch)
#    2508 layout_patch = layout_patch or {}
#    2509 apply_default_cascade(args, constructor=constructor)
# -> 2511 args = build_dataframe(args, constructor)
#    2512 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2513     args = process_dataframe_hierarchy(args)
#
# File e:\AI Projects\myenv\Lib\site-packages\plotly\express\_core.py:1757, in build_dataframe(args, constructor)
#    1754     args["color"] = None
#    1755 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1757 df_output, wide_id_vars = process_args_into_dataframe(
#    1758     args,
#    1759     wide_mode,
#    1760     var_name,
#    1761     value_name,
#    1762     is_pd_like,
#    1763     native_namespace,
#    1764 )
#    1765 df_output: nw.DataFrame
#    1766 # now that `df_output` exists and `args` contains only references, we complete
#    1767 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1768 # df_output
#
# File e:\AI Projects\myenv\Lib\site-packages\plotly\express\_core.py:1392, in process_args_into_dataframe(args, wide_mode, var_name, value_name, is_pd_like, native_namespace)
#    1384         col_name = _escape_col_name(
#    1385             df_input.columns, col_name, [var_name, value_name]
#    1386         )
#    1387     else:
#    1388         if (
#    1389             argument.name is not None
#    1390             and argument.name in df_input.columns
#    1391             and (
# -> 1392                 to_named_series(
#    1393                     argument, argument.name, native_namespace
#    1394                 )
#    1395                 == df_input.get_column(argument.name)
#    1396             ).all()
#    1397         ):
#    1398             col_name = argument.name
#    1399 if col_name is None:  # numpy array, list...
#
# File e:\AI Projects\myenv\Lib\site-packages\narwhals\series.py:1720, in Series.__eq__(self, other)
#    1718 def __eq__(self, other: object) -> Self:  # type: ignore[override]
#    1719     return self._with_compliant(
# -> 1720         self._compliant_series.__eq__(self._extract_native(other))
#    1721     )
#
# File e:\AI Projects\myenv\Lib\site-packages\narwhals\_pandas_like\series.py:413, in PandasLikeSeries.__eq__(self, other)
#     412 def __eq__(self, other: object) -> Self:  # type: ignore[override]
# --> 413     return self._with_binary(operator.eq, other)
#
# File e:\AI Projects\myenv\Lib\site-packages\narwhals\_pandas_like\series.py:403, in PandasLikeSeries._with_binary(self, op, other)
#     402 def _with_binary(self, op: Callable[..., PandasLikeSeries], other: Any) -> Self:
# --> 403     ser, other_native = align_and_extract_native(self, other)
#     404     preserve_broadcast = self._broadcast and getattr(other, "_broadcast", True)
#     405     return self._with_native(
#     406         op(ser, other_native), preserve_broadcast=preserve_broadcast
#     407     ).alias(self.name)
#
# File e:\AI Projects\myenv\Lib\site-packages\narwhals\_pandas_like\utils.py:152, in align_and_extract_native(lhs, rhs)
#     148         return (lhs.native, rhs.native.iloc[0])
#     149     if rhs.native.index is not lhs_index:
#     150         return (
#     151             lhs.native,
# --> 152             set_index(rhs.native, lhs_index, implementation=rhs._implementation),
#     153         )
#     154     return (lhs.native, rhs.native)
#     156 if isinstance(rhs, list):
#
# File e:\AI Projects\myenv\Lib\site-packages\narwhals\_pandas_like\utils.py:175, in set_index(obj, index, implementation)
#     171 if isinstance(index, implementation.to_native_namespace().Index) and (
#     172     expected_len := len(index)
#     173 ) != (actual_len := len(obj)):
#     174     msg = f"Expected object of length {expected_len}, got length: {actual_len}"
# --> 175     raise ShapeError(msg)
#     176 if implementation is Implementation.CUDF:
#     177     obj = obj.copy(deep=False)
#
# ShapeError: Expected object of length 5, got length: 460256

# %%
text = " ".join(i for i in data.content)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
nltk.download('vader_lexicon')
sentiments = SentimentIntensityAnalyzer()
data["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data["content"]]
data["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data["content"]]
data["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data["content"]]
data = data[["content", "Positive", "Negative", "Neutral"]]
data.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
#                                              content  Positive  Negative  \
# 0                                           No words     0.000     0.688
# 1                              Great fun app so far!     0.719     0.000
# 2  The app would get a higher rating but I litera...     0.000     0.073
# 3  I WISH I COULD GIVE THIS A 100 PERCENT RATING ...     0.561     0.000
# 4                                Pictures and record     0.000     0.000
#
#    Neutral
# 0    0.312
# 1    0.281
# 2    0.927
# 3    0.439
# 4    1.000

# %%
positive =' '.join([i for i in data['content'][data['Positive'] > data["Negative"]]])
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(positive)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
negative =' '.join([i for i in data['content'][data['Negative'] > data["Positive"]]])
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(negative)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
x = sum(data["Positive"])
y = sum(data["Negative"])
z = sum(data["Neutral"])

def sentiment_score(a, b, c):
    if (a>b) and (a>c):
        print("Positive 😊 ")
    elif (b>a) and (b>c):
        print("Negative 😠 ")
    else:
        print("Neutral 🙂 ")
sentiment_score(x, y, z)
# Out:
# Neutral 🙂

# %%
print("Positive: ", x)
print("Negative: ", y)
print("Neutral: ", z)
# Out:
# Positive:  196353.479
# Negative:  16512.736
# Neutral:  244154.793
